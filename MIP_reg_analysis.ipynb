# %% [markdown]
# #MIP Regression Analysis

# %% [markdown]
# This script analyses the data generated by the merger of the ownership data and the company panel information

# %%
import pandas as pd
import numpy as np
import statsmodels.formula.api as smf

# %% [markdown]
# Load the datasets

# %%
df_merged_companies = pd.read_csv(r"C:\Users\lucas\OneDrive\BA\Data\outputs\merged_companies.csv")
df_merged_owners = pd.read_csv(r"C:\Users\lucas\OneDrive\BA\Data\outputs\merged_owners.csv")
# Out:
# C:\Users\lucas\AppData\Local\Temp\ipykernel_30156\2616293258.py:1: DtypeWarning: Columns (19,29,48,49,50,51,52,53,55,63,74,75,76,77,78,79,80,81,84,85,88,89,93,98,101,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,134,135,136,137,142,143,144,159,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,199,200,206,208,209,210,211,213,217,218,219,220,231,235,236,237,238,239,240,247,248,251,252,254,255,256,257,258,260,262,263,264,265,266,267,268,269,270,271,272,273,274,275,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,304,305,306,307,308,310,312,314,316,318,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,363,364,365,366,367,368,369,370,371,372,373,374,386,400,404,408,409,410,411,412,413,427,429,435,438,439,440,441,442,443,444,445,446,447,448,449,450,464,467,469,472,474,477,479,482,484,487,489,492,494,497,499,500,501,502,503,504,505,506,507,508,509,510,511,512,513,514,515,516,517,518,519,520,540,541,542,549,550,551,553,554,555,556,557,558,559,560,562,565,566,567,568,569,570,571,572,573,574,575,576,577,578,579,580,581,582,583,584,585,586,587,588,589,590,591,592,593,595,598,605,608,612,613,614,617,620,621,622,624,625,626,627,628,629,637,638,639,644,645,646,647,648,649,651,656,657,658,659,661,662,663,664,665,666,667,668,669,670,671,672,673,674,675,676,677,678,679,680,681,682,683,684,685,686,687,688,689,690,691,692,693,694,695,696,697,698,699,700,701,702,703,704,705,706,708,709,710,711,712,713,714,715,716,717,718,719,720,721,722,723,725,726,727,728,729,730,731,733,735,737,738,741,743,756,757,758,759,760,761,762,766,769,772,774,778,779,780,781,782,783,784,786,787,790,791,792,793,794,795,796,797,798,799,800,801,802,803,804,805,806,807,808,809,810,811,812,813,814,815,816,817,818,819,820,821,822,823,824,825,826,827,828,829,830,831,832,833,834,835,836,837,838,842,845,847,851,855,858,861,862,863,864,865,869,870,871,872,873,875,877,880,884,887,890,893,896,899,902,907,913,918,920,921,922,923,924,925,926,927,928,929,930,931,932,933,934,935,936,937,938,939,940,941,942,943,944,945,946,947,948,952,954,956,960,962,963,965,967,968,969,970,978,981,982,983,984,985,986,987,988,989,990,991,992,993,994,995,996,997,998,999,1000,1001,1002,1003,1004,1005,1006,1007,1008,1009,1010,1011,1012,1013,1014,1015,1016,1017,1018,1029,1032,1034,1037,1038,1039,1040,1041,1042,1043,1044,1045,1046,1057,1058,1059,1060,1061,1062,1063,1064,1065,1066,1067,1068,1069,1070,1071,1072,1073,1093,1095,1097,1099,1101,1105,1106,1115,1116,1117,1118,1119,1120,1121,1122,1123,1124,1125,1126,1127,1128,1129,1130,1131,1132,1133,1134,1135,1136,1137,1138,1139,1140,1141,1142,1143,1144,1145,1146,1147,1160,1162,1163,1164,1165,1171,1181,1183,1184,1185,1186,1187,1188,1189,1190,1191,1192,1193,1194,1195,1196,1197,1198,1199,1200,1201,1202,1203,1204,1205,1206,1207,1208,1209,1210,1212,1213,1214,1215,1216,1217,1218,1224,1226,1228,1230,1232,1246,1264,1284,1294,1300,1301,1302,1303,1304,1305,1306,1307,1308,1309,1310,1316,1318,1319,1321,1323,1325,1326,1328,1329,1330,1331,1332,1333,1334,1335,1336,1337,1338,1339,1340,1341,1342,1343,1344,1345,1346,1347,1348,1349,1350,1351,1352,1353,1354,1355,1356,1357,1358,1359,1360,1361,1362,1363,1364,1365,1366,1367,1368,1369,1370,1371,1372,1373,1374,1375,1376,1377,1378,1379,1380,1381,1382,1383,1384,1385,1386,1387,1388,1389,1390,1391,1392,1393,1394,1395,1396,1397,1398,1399,1400,1401,1402,1403,1404,1405,1407,1408,1409,1410,1411,1412,1413,1414,1416,1420,1421,1422,1426,1427,1428,1429,1430,1431,1432,1433,1434,1435,1436,1437,1438,1439,1440,1441,1442,1446,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1462,1463,1464,1465,1466,1467,1468,1469,1470,1471,1472,1474,1475,1476,1477,1478,1485,1487,1489,1491,1499,1501,1502,1503,1 ...
#   df_merged_companies = pd.read_csv(r"C:\Users\lucas\OneDrive\BA\Data\outputs\merged_companies.csv")
# C:\Users\lucas\AppData\Local\Temp\ipykernel_30156\2616293258.py:2: DtypeWarning: Columns (8,92,93,158,159,160,161,162,163,164,165,166,167,168,169,170,171,177,178,179,180,181,182,183,184,185,186,189,198,199,200,208,224,225,226,227,228,229,254,256,262,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,358,359,360,361,362,488,539,555,556,557,558,602,616,617,627,628,645,646,650,651,652,653,654,655,656,657,658,659,660,661,662,663,664,665,666,667,668,669,670,671,672,745,746,747,748,749,750,751,763,779,780,781,782,783,784,785,786,787,788,789,790,791,792,793,794,795,796,797,798,799,800,801,802,803,804,805,806,807,808,809,810,811,812,813,814,815,816,817,818,819,820,821,822,823,850,851,907,909,913,914,915,954,970,972,973,974,975,976,977,978,979,980,981,983,984,985,986,987,988,989,990,991,993,994,995,996,997,998,999,1000,1001,1002,1004,1005,1006,1023,1026,1027,1028,1029,1030,1031,1032,1033,1034,1035,1047,1048,1049,1050,1051,1052,1053,1054,1055,1056,1057,1058,1059,1060,1061,1062,1090,1094,1095,1151,1153,1154,1160,1170,1172,1173,1174,1175,1176,1177,1178,1179,1180,1181,1182,1183,1184,1185,1187,1188,1189,1190,1191,1192,1193,1194,1202,1203,1204,1205,1206,1207,1213,1215,1217,1219,1221,1235,1253,1273,1283,1289,1290,1291,1292,1293,1294,1295,1296,1297,1298,1299,1305,1314,1317,1318,1320,1321,1323,1324,1326,1327,1329,1330,1332,1333,1335,1336,1337,1338,1339,1340,1342,1343,1344,1345,1346,1347,1348,1350,1351,1352,1353,1354,1355,1356,1357,1359,1360,1362,1363,1365,1366,1368,1369,1371,1372,1374,1375,1377,1378,1379,1380,1381,1382,1383,1384,1385,1386,1387,1388,1389,1390,1391,1392,1393,1394,1396,1397,1398,1399,1400,1401,1403,1410,1411,1426,1429,1430,1431,1435,1436,1437,1438,1439,1440,1441,1442,1443,1444,1445,1446,1447,1448,1449,1450,1451,1452,1453,1454,1455,1456,1457,1458,1459,1460,1461,1463,1464,1465,1466,1467,1480,1490,1491,1492,1493,1494,1496,1511,1522,1530,1533,1536,1540,1541,1549,1551,1579,1581) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_merged_owners = pd.read_csv(r"C:\Users\lucas\OneDrive\BA\Data\outputs\merged_owners.csv")

# %% [markdown]
# Two columns indicating if the company was involved in a ownership change in any of the panel years, one for `b_crefo` and one for `ownerid`

# %%
df_merged_companies["is_owner_change_company"] = df_merged_companies.groupby(["companyid"])["is_owner_change"].transform('any')
df_merged_companies["is_ownerid_change_company"] = df_merged_companies.groupby(["companyid"])["is_ownerid_change"].transform('any')

# %% [markdown]
# Further six columns are added, in order to indicate when the ownership change took place. The periods are constructed so that there is cleary a survey before and after the acquisition (2009, whose period is 2006-2008; 2015, whose period is 2012-2014; and 2021, which emcompasses 2018-2020)
#
# Change of ownership based on `b_crefo`:
# - 2009-2011 = `is_owner_change_2009`
# - 2015-2017 = `is_owner_change_2015`
# - 2009-2017 = `is_owner_change_2009_2017`
#
# Change of ownership based on `ownerid`:
# - 2009-2011 = `is_ownerid_change_2009`
# - 2015-2017 = `is_ownerid_change_2015`
# - 2009-2017 = `is_ownerid_change_2009_2017`

# %%
# b_crefo, 2009-2014
df_merged_companies["is_owner_change_2009"] = np.where((df_merged_companies["is_owner_change"] == True) & (df_merged_companies["panel_year"] > 2008) & (df_merged_companies["panel_year"] < 2012), True, False)
df_merged_companies["is_owner_change_2009"] = df_merged_companies.groupby(["companyid"])["is_owner_change_2009"].transform('any')

# b_crefo, 2015-2017
df_merged_companies["is_owner_change_2015"] = np.where((df_merged_companies["is_owner_change"] == True) & (df_merged_companies["panel_year"] > 2014) & (df_merged_companies["panel_year"] < 2018), True, False)
df_merged_companies["is_owner_change_2015"] = df_merged_companies.groupby(["companyid"])["is_owner_change_2015"].transform('any')

# b_crefo, 2009-2017
df_merged_companies["is_owner_change_2009_2017"] = np.where((df_merged_companies["is_owner_change"] == True) & (df_merged_companies["panel_year"] > 2008) & (df_merged_companies["panel_year"] < 2018), True, False)
df_merged_companies["is_owner_change_2009_2017"] = df_merged_companies.groupby(["companyid"])["is_owner_change_2009_2017"].transform('any')

# ownerid, 2009-2014
df_merged_companies["is_ownerid_change_2009"] = np.where((df_merged_companies["is_ownerid_change"] == True) & (df_merged_companies["panel_year"] > 2008) & (df_merged_companies["panel_year"] < 2012), True, False)
df_merged_companies["is_ownerid_change_2009"] = df_merged_companies.groupby(["companyid"])["is_ownerid_change_2009"].transform('any')

# ownerid, 2015-2017
df_merged_companies["is_ownerid_change_2015"] = np.where((df_merged_companies["is_ownerid_change"] == True) & (df_merged_companies["panel_year"] > 2014) & (df_merged_companies["panel_year"] < 2018), True, False)
df_merged_companies["is_ownerid_change_2015"] = df_merged_companies.groupby(["companyid"])["is_ownerid_change_2015"].transform('any')

# ownerid, 2009-2017
df_merged_companies["is_ownerid_change_2009_2017"] = np.where((df_merged_companies["is_ownerid_change"] == True) & (df_merged_companies["panel_year"] > 2008) & (df_merged_companies["panel_year"] < 2018), True, False)
df_merged_companies["is_ownerid_change_2009_2017"] = df_merged_companies.groupby(["companyid"])["is_ownerid_change_2009_2017"].transform('any')

# %% [markdown]
# Now for `df_merged_owners` with `ownerid`

# %%
# ownerid, 2009-2014
df_merged_owners["is_ownerid_change_2009"] = np.where((df_merged_owners["is_ownerid_change"] == True) & (df_merged_owners["panel_year"] > 2008) & (df_merged_owners["panel_year"] < 2012), True, False)
df_merged_owners["is_ownerid_change_2009"] = df_merged_owners.groupby(["companyid"])["is_ownerid_change_2009"].transform('any')

# ownerid, 2015-2017
df_merged_owners["is_ownerid_change_2015"] = np.where((df_merged_owners["is_ownerid_change"] == True) & (df_merged_owners["panel_year"] > 2014) & (df_merged_owners["panel_year"] < 2018), True, False)
df_merged_owners["is_ownerid_change_2015"] = df_merged_owners.groupby(["companyid"])["is_ownerid_change_2015"].transform('any')

# ownerid, 2009-2017
df_merged_owners["is_ownerid_change_2009_2017"] = np.where((df_merged_owners["is_ownerid_change"] == True) & (df_merged_owners["panel_year"] > 2008) & (df_merged_owners["panel_year"] < 2018), True, False)
df_merged_owners["is_ownerid_change_2009_2017"] = df_merged_owners.groupby(["companyid"])["is_ownerid_change_2009_2017"].transform('any')

# %% [markdown]
# As previously discussed in the MIP merge file, the environmental innovations survey questions changed from 2009 to 2015 and 2021, and due to that, the individual variables do not all have the same meaning depending on the year (e.g. `oekpz6` in 2015 onwards refers to noise pollution, while in 2009 it refers to soil contamination). Therefore, I will construct the variables `oekpz_avg` and `oekpd_avg`, which are averages of the other variables and can show a holistic view of eco-innovation at the respective companies.

# %%
eco_innovations = ["oekpz1", "oekpz2", "oekpz3", "oekpz4", "oekpz5", "oekpz6", "oekpz7", "oekpz8", "oekpz9"] 
eco_product_innovations = ["oekpd1", "oekpd2", "oekpd3", "oekpd4"]
df_merged_companies["oekpz_avg"] = df_merged_companies[eco_innovations].mean(axis=1)
df_merged_companies["oekpd_avg"] = df_merged_companies[eco_product_innovations].mean(axis=1)
df_merged_owners["oekpz_avg"] = df_merged_owners[eco_innovations].mean(axis=1)
df_merged_owners["oekpd_avg"] = df_merged_owners[eco_product_innovations].mean(axis=1)

# %% [markdown]
# However, in other to not lose information through the aggregation of all the variables into averages, I matched, were it was possible, the different variables throughout the years. The variable descriptions as they appear in the scientific use guide for MIP will be commented.

# %%
#oekpz1, 2015/2021: Reduction of energy consumption
#oekpz2, 2009: Reduction in energy consumption 
df_merged_companies["energy_consumption"] = np.where((df_merged_companies["jahr"] == 2014) | (df_merged_companies["jahr"] == 2020), df_merged_companies["oekpz1"], df_merged_companies["oekpz2"])
df_merged_owners["energy_consumption"] = np.where((df_merged_owners["jahr"] == 2014) | (df_merged_owners["jahr"] == 2020), df_merged_owners["oekpz1"], df_merged_owners["oekpz2"])

# %%
#oekpz2, 2015/2021: Reduction of material / water consumption
#oekpz1, 2009: Reduction in material use
df_merged_companies["material_use"] = np.where((df_merged_companies["jahr"] == 2014) | (df_merged_companies["jahr"] == 2020), df_merged_companies["oekpz2"], df_merged_companies["oekpz1"])
df_merged_owners["material_use"] = np.where((df_merged_owners["jahr"] == 2014) | (df_merged_owners["jahr"] == 2020), df_merged_owners["oekpz2"], df_merged_owners["oekpz1"])

# %%
#oekpz3: Reduction of CO2 emissions (2009, 2015/2021)
df_merged_companies["emissions_CO2"] = df_merged_companies["oekpz3"]
df_merged_owners["emissions_CO2"] = df_merged_owners["oekpz3"]
#oekpz4: Reduction of other air pollution (2015/2021), Reduction of other emissions (2009) 
df_merged_companies["emissions_other"] = df_merged_companies["oekpz4"]
df_merged_owners["emissions_other"] = df_merged_owners["oekpz4"]
#oekpz8: Replacement of dangerous material (2015/2021), Replacement of hazardous material (2009)
df_merged_companies["hazardous_material"] = df_merged_companies["oekpz8"]
df_merged_owners["hazardous_material"] = df_merged_owners["oekpz8"]
#oekpz9: Recycling of waste / waste water / material (2015/2021), Improvement in recycling (2009)
df_merged_companies["recycling"] = df_merged_companies["oekpz9"]
df_merged_owners["recycling"] = df_merged_owners["oekpz9"]

# %% [markdown]
# #Regression

# %% [markdown]
# Define all possible dependent variables

# %%
dependent_variables = ["oekpz_avg", "oekpd_avg", "energy_consumption", "material_use", "emissions_CO2", "emissions_other", "hazardous_material", "recycling"]

# %% [markdown]
# Regression with no control variables, merger between 2009-2011

# %%
#Loop over all possible dependent variables
for y in dependent_variables:
    # Filter the data for the relevant years
    df_did = df_merged_companies[(df_merged_companies["jahr"] == 2008) | (df_merged_companies["jahr"] == 2014)]
    df_did = df_did[["companyid", "jahr", y, "is_owner_change_2009", "is_owner_change_2015", "is_owner_change_2009_2017"]]
    df_did["jahr_2014"] = np.where(df_did["jahr"] == 2014, 1, 0)
    df_did["is_owner_change_2009"] = np.where(df_did["is_owner_change_2009"] == True, 1, 0)

    # Set up the difference-in-differences model
    model_did = smf.ols(formula= y + ' ~ is_owner_change_2009 + jahr_2014 + is_owner_change_2009:jahr_2014', data=df_did)

    # Fit the model
    results_did = model_did.fit()

    # Print the model summary
    print("Regression results for " + y + " in the period 2009-2011:\n")
    print(results_did.summary())
    print("\n\n")
# Out:
# Regression results for oekpz_avg in the period 2009-2011:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              oekpz_avg   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     44.85
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           9.20e-29
# Time:                        18:13:44   Log-Likelihood:                -7004.2
# No. Observations:                8938   AIC:                         1.402e+04
# Df Residuals:                    8934   BIC:                         1.404e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.4565      0.008     56.365      0.000       0.441       0.472
# is_owner_change_2009              -0.0027      0.027     -0.104      0.918      -0.055       0.049
# jahr_2014                         -0.1326      0.012    -11.266      0.000      -0.156      -0.110
# is_owner_change_2009:jahr_2014     0.0329      0.039      0.837      0.403      -0.044       0.110
# ==============================================================================
# Omnibus:                     1935.545   Durbin-Watson:                   1.877
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3478.300
# Skew:                           1.405   Prob(JB):                         0.00
# Kurtosis:                       4.201   Cond. No.                         8.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for oekpd_avg in the period 2009-2011:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              oekpd_avg   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     65.14
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           1.19e-41
# Time:                        18:13:44   Log-Likelihood:                -7731.2
# No. Observations:                8813   AIC:                         1.547e+04
# Df Residuals:                    8809   BIC:                         1.550e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.4565      0.009     51.120      0.000       0.439       0.474
# is_owner_change_2009              -0.0312      0.029     -1.062      0.288      -0.089       0.026
# jahr_2014                         -0.1743      0.013    -13.393      0.000      -0.200      -0.149
# is_owner_change_2009:jahr_2014     0.0126      0.044      0.289      0.773      -0.073       0.098
# ==============================================================================
# Omnibus:                     1823.398   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3162.601
# Skew:                           1.400   Prob(JB):                         0.00
# Kurtosis:                       3.879   Cond. No.                         8.98
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for energy_consumption in the period 2009-2011:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     energy_consumption   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     4.008
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):            0.00733
# Time:                        18:13:44   Log-Likelihood:                -10232.
# No. Observations:                8813   AIC:                         2.047e+04
# Df Residuals:                    8809   BIC:                         2.050e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.6142      0.012     51.637      0.000       0.591       0.637
# is_owner_change_2009               0.0363      0.039      0.930      0.352      -0.040       0.113
# jahr_2014                         -0.0531      0.017     -3.071      0.002      -0.087      -0.019
# is_owner_change_2009:jahr_2014    -0.0074      0.058     -0.127      0.899      -0.121       0.106
# ==============================================================================
# Omnibus:                     1686.555   Durbin-Watson:                   1.890
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1285.575
# Skew:                           0.836   Prob(JB):                    6.93e-280
# Kurtosis:                       2.162   Cond. No.                         8.98
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for material_use in the period 2009-2011:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           material_use   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     51.00
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           1.14e-32
# Time:                        18:13:45   Log-Likelihood:                -9492.8
# No. Observations:                8752   AIC:                         1.899e+04
# Df Residuals:                    8748   BIC:                         1.902e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.5453      0.011     49.441      0.000       0.524       0.567
# is_owner_change_2009               0.0258      0.036      0.710      0.478      -0.045       0.097
# jahr_2014                         -0.1893      0.016    -11.782      0.000      -0.221      -0.158
# is_owner_change_2009:jahr_2014     0.0059      0.054      0.109      0.913      -0.100       0.111
# ==============================================================================
# Omnibus:                     1300.386   Durbin-Watson:                   1.918
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1981.622
# Skew:                           1.164   Prob(JB):                         0.00
# Kurtosis:                       2.894   Cond. No.                         8.97
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for emissions_CO2 in the period 2009-2011:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          emissions_CO2   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     42.72
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           2.14e-27
# Time:                        18:13:45   Log-Likelihood:                -9406.4
# No. Observations:                8701   AIC:                         1.882e+04
# Df Residuals:                    8697   BIC:                         1.885e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.5048      0.011     45.829      0.000       0.483       0.526
# is_owner_change_2009               0.0103      0.036      0.286      0.775      -0.060       0.081
# jahr_2014                         -0.1755      0.016    -10.925      0.000      -0.207      -0.144
# is_owner_change_2009:jahr_2014     0.0339      0.054      0.630      0.529      -0.072       0.140
# ==============================================================================
# Omnibus:                     1536.387   Durbin-Watson:                   1.934
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2516.939
# Skew:                           1.313   Prob(JB):                         0.00
# Kurtosis:                       3.214   Cond. No.                         8.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for emissions_other in the period 2009-2011:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        emissions_other   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     45.02
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           7.33e-29
# Time:                        18:13:46   Log-Likelihood:                -8125.9
# No. Observations:                8639   AIC:                         1.626e+04
# Df Residuals:                    8635   BIC:                         1.629e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.3632      0.010     37.822      0.000       0.344       0.382
# is_owner_change_2009               0.0294      0.031      0.933      0.351      -0.032       0.091
# jahr_2014                         -0.1550      0.014    -11.068      0.000      -0.182      -0.128
# is_owner_change_2009:jahr_2014     0.0161      0.047      0.343      0.731      -0.076       0.108
# ==============================================================================
# Omnibus:                     2801.603   Durbin-Watson:                   1.892
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6706.627
# Skew:                           1.874   Prob(JB):                         0.00
# Kurtosis:                       5.142   Cond. No.                         8.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for hazardous_material in the period 2009-2011:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     hazardous_material   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     40.89
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           3.16e-26
# Time:                        18:13:46   Log-Likelihood:                -8021.3
# No. Observations:                8624   AIC:                         1.605e+04
# Df Residuals:                    8620   BIC:                         1.608e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.3659      0.010     38.453      0.000       0.347       0.385
# is_owner_change_2009              -0.0647      0.031     -2.071      0.038      -0.126      -0.003
# jahr_2014                         -0.1513      0.014    -10.901      0.000      -0.178      -0.124
# is_owner_change_2009:jahr_2014     0.0802      0.046      1.731      0.084      -0.011       0.171
# ==============================================================================
# Omnibus:                     2803.678   Durbin-Watson:                   1.900
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6743.262
# Skew:                           1.874   Prob(JB):                         0.00
# Kurtosis:                       5.173   Cond. No.                         8.95
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for recycling in the period 2009-2011:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              recycling   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     62.31
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           7.46e-40
# Time:                        18:13:47   Log-Likelihood:                -9544.9
# No. Observations:                8698   AIC:                         1.910e+04
# Df Residuals:                    8694   BIC:                         1.913e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.5599      0.011     50.021      0.000       0.538       0.582
# is_owner_change_2009              -0.0401      0.037     -1.091      0.275      -0.112       0.032
# jahr_2014                         -0.2181      0.016    -13.356      0.000      -0.250      -0.186
# is_owner_change_2009:jahr_2014     0.0658      0.055      1.203      0.229      -0.041       0.173
# ==============================================================================
# Omnibus:                     1331.523   Durbin-Watson:                   1.871
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2058.045
# Skew:                           1.191   Prob(JB):                         0.00
# Kurtosis:                       2.936   Cond. No.                         8.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Regression with no control variables, mergers between 2015-2017

# %%
#Loop over all possible dependent variables
for y in dependent_variables:
    # Filter the data for the relevant years
    df_did = df_merged_companies[(df_merged_companies["jahr"] == 2014) | (df_merged_companies["jahr"] == 2020)]
    df_did = df_did[["companyid", "jahr", y, "is_owner_change_2015"]]
    df_did["jahr_2020"] = np.where(df_did["jahr"] == 2020, 1, 0)
    df_did["is_owner_change_2015"] = np.where(df_did["is_owner_change_2015"] == True, 1, 0)

    # Set up the difference-in-differences model
    model_did = smf.ols(formula= y + ' ~ is_owner_change_2015 + jahr_2020 + is_owner_change_2015:jahr_2020', data=df_did)

    # Fit the model
    results_did = model_did.fit()

    # Print the model summary
    print("Regression results for " + y + " in the period 2015-2017:\n")
    print(results_did.summary())
    print("\n\n")
# Out:
# Regression results for oekpz_avg in the period 2015-2017:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              oekpz_avg   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.509
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):              0.210
# Time:                        18:13:47   Log-Likelihood:                -5161.5
# No. Observations:                8213   AIC:                         1.033e+04
# Df Residuals:                    8209   BIC:                         1.036e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.3275      0.007     44.615      0.000       0.313       0.342
# is_owner_change_2015              -0.0108      0.024     -0.453      0.651      -0.058       0.036
# jahr_2020                          0.0196      0.011      1.862      0.063      -0.001       0.040
# is_owner_change_2015:jahr_2020     0.0128      0.034      0.374      0.709      -0.054       0.080
# ==============================================================================
# Omnibus:                     2314.138   Durbin-Watson:                   1.835
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5312.820
# Skew:                           1.610   Prob(JB):                         0.00
# Kurtosis:                       5.270   Cond. No.                         8.93
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for oekpd_avg in the period 2015-2017:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              oekpd_avg   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     33.25
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           2.39e-21
# Time:                        18:13:48   Log-Likelihood:                -5881.4
# No. Observations:                8071   AIC:                         1.177e+04
# Df Residuals:                    8067   BIC:                         1.180e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.2821      0.008     34.407      0.000       0.266       0.298
# is_owner_change_2015              -0.0150      0.027     -0.560      0.575      -0.067       0.037
# jahr_2020                          0.1074      0.012      9.148      0.000       0.084       0.130
# is_owner_change_2015:jahr_2020     0.0375      0.038      0.985      0.325      -0.037       0.112
# ==============================================================================
# Omnibus:                     2052.204   Durbin-Watson:                   1.858
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4145.296
# Skew:                           1.543   Prob(JB):                         0.00
# Kurtosis:                       4.674   Cond. No.                         8.93
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for energy_consumption in the period 2015-2017:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     energy_consumption   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.573
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):              0.194
# Time:                        18:13:48   Log-Likelihood:                -8725.6
# No. Observations:                8121   AIC:                         1.746e+04
# Df Residuals:                    8117   BIC:                         1.749e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.5615      0.012     48.610      0.000       0.539       0.584
# is_owner_change_2015               0.0223      0.038      0.593      0.553      -0.051       0.096
# jahr_2020                         -0.0312      0.017     -1.886      0.059      -0.064       0.001
# is_owner_change_2015:jahr_2020    -0.0169      0.054     -0.316      0.752      -0.122       0.088
# ==============================================================================
# Omnibus:                      980.317   Durbin-Watson:                   1.856
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1186.619
# Skew:                           0.902   Prob(JB):                    2.13e-258
# Kurtosis:                       2.496   Cond. No.                         8.92
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for material_use in the period 2015-2017:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           material_use   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                    0.4557
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):              0.713
# Time:                        18:13:48   Log-Likelihood:                -7357.1
# No. Observations:                8038   AIC:                         1.472e+04
# Df Residuals:                    8034   BIC:                         1.475e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.3561      0.010     35.922      0.000       0.337       0.376
# is_owner_change_2015               0.0275      0.032      0.857      0.392      -0.035       0.091
# jahr_2020                          0.0048      0.014      0.340      0.734      -0.023       0.033
# is_owner_change_2015:jahr_2020    -0.0038      0.046     -0.084      0.933      -0.094       0.086
# ==============================================================================
# Omnibus:                     1778.997   Durbin-Watson:                   1.872
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3198.969
# Skew:                           1.460   Prob(JB):                         0.00
# Kurtosis:                       4.015   Cond. No.                         8.91
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for emissions_CO2 in the period 2015-2017:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          emissions_CO2   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     15.81
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           3.03e-10
# Time:                        18:13:49   Log-Likelihood:                -7745.1
# No. Observations:                8005   AIC:                         1.550e+04
# Df Residuals:                    8001   BIC:                         1.553e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.3358      0.010     32.025      0.000       0.315       0.356
# is_owner_change_2015              -0.0285      0.034     -0.834      0.404      -0.095       0.038
# jahr_2020                          0.0904      0.015      6.039      0.000       0.061       0.120
# is_owner_change_2015:jahr_2020     0.0624      0.049      1.285      0.199      -0.033       0.158
# ==============================================================================
# Omnibus:                     1726.013   Durbin-Watson:                   1.864
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3055.672
# Skew:                           1.448   Prob(JB):                         0.00
# Kurtosis:                       3.883   Cond. No.                         8.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for emissions_other in the period 2015-2017:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        emissions_other   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     6.720
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           0.000159
# Time:                        18:13:49   Log-Likelihood:                -6200.4
# No. Observations:                7949   AIC:                         1.241e+04
# Df Residuals:                    7945   BIC:                         1.244e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.2125      0.009     24.353      0.000       0.195       0.230
# is_owner_change_2015              -0.0052      0.028     -0.182      0.856      -0.061       0.051
# jahr_2020                          0.0477      0.012      3.829      0.000       0.023       0.072
# is_owner_change_2015:jahr_2020     0.0383      0.040      0.949      0.343      -0.041       0.117
# ==============================================================================
# Omnibus:                     3265.314   Durbin-Watson:                   1.923
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10896.014
# Skew:                           2.169   Prob(JB):                         0.00
# Kurtosis:                       6.752   Cond. No.                         8.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for hazardous_material in the period 2015-2017:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     hazardous_material   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.345
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):              0.258
# Time:                        18:13:50   Log-Likelihood:                -5934.6
# No. Observations:                7919   AIC:                         1.188e+04
# Df Residuals:                    7915   BIC:                         1.191e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.2141      0.008     25.281      0.000       0.197       0.231
# is_owner_change_2015               0.0203      0.027      0.740      0.459      -0.034       0.074
# jahr_2020                          0.0216      0.012      1.784      0.075      -0.002       0.045
# is_owner_change_2015:jahr_2020    -0.0538      0.039     -1.378      0.168      -0.130       0.023
# ==============================================================================
# Omnibus:                     3414.505   Durbin-Watson:                   1.879
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12328.096
# Skew:                           2.247   Prob(JB):                         0.00
# Kurtosis:                       7.144   Cond. No.                         8.91
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for recycling in the period 2015-2017:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              recycling   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     4.188
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):            0.00570
# Time:                        18:13:50   Log-Likelihood:                -7676.9
# No. Observations:                7939   AIC:                         1.536e+04
# Df Residuals:                    7935   BIC:                         1.539e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.3464      0.010     33.039      0.000       0.326       0.367
# is_owner_change_2015              -0.0243      0.034     -0.712      0.476      -0.091       0.043
# jahr_2020                          0.0449      0.015      2.987      0.003       0.015       0.074
# is_owner_change_2015:jahr_2020     0.0432      0.049      0.889      0.374      -0.052       0.139
# ==============================================================================
# Omnibus:                     1828.468   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3356.982
# Skew:                           1.509   Prob(JB):                         0.00
# Kurtosis:                       4.017   Cond. No.                         8.91
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Regression with no control variables, mergers between 2009-2017

# %%
#Loop over all possible dependent variables
for y in dependent_variables:
    # Filter the data for the relevant years
    df_did = df_merged_companies[(df_merged_companies["jahr"] == 2008) | (df_merged_companies["jahr"] == 2020)]
    df_did = df_did[["companyid", "jahr", y, "is_owner_change_2009_2017"]]
    df_did["jahr_2020"] = np.where(df_did["jahr"] == 2020, 1, 0)
    df_did["is_owner_change_2009_2017"] = np.where(df_did["is_owner_change_2009_2017"] == True, 1, 0)

    # Set up the difference-in-differences model
    model_did = smf.ols(formula=y + ' ~ is_owner_change_2009_2017 + jahr_2020 + is_owner_change_2009_2017:jahr_2020', data=df_did)

    # Fit the model
    results_did = model_did.fit()

    # Print the model summary
    print("Regression results for " + y + " in the period 2009-2017:\n")
    print(results_did.summary())
    print("\n\n")
# Out:
# Regression results for oekpz_avg in the period 2009-2017:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              oekpz_avg   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     31.52
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           2.93e-20
# Time:                        18:13:51   Log-Likelihood:                -6777.4
# No. Observations:                8717   AIC:                         1.356e+04
# Df Residuals:                    8713   BIC:                         1.359e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.4558      0.009     51.895      0.000       0.439       0.473
# is_owner_change_2009_2017               0.0017      0.018      0.095      0.924      -0.034       0.037
# jahr_2020                              -0.1150      0.013     -8.883      0.000      -0.140      -0.090
# is_owner_change_2009_2017:jahr_2020     0.0263      0.027      0.986      0.324      -0.026       0.079
# ==============================================================================
# Omnibus:                     1749.843   Durbin-Watson:                   1.943
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3007.996
# Skew:                           1.342   Prob(JB):                         0.00
# Kurtosis:                       4.039   Cond. No.                         6.35
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for oekpd_avg in the period 2009-2017:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              oekpd_avg   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     8.916
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           6.78e-06
# Time:                        18:13:51   Log-Likelihood:                -7880.5
# No. Observations:                8616   AIC:                         1.577e+04
# Df Residuals:                    8612   BIC:                         1.580e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.4534      0.010     44.826      0.000       0.434       0.473
# is_owner_change_2009_2017               0.0007      0.021      0.035      0.972      -0.040       0.041
# jahr_2020                              -0.0728      0.015     -4.869      0.000      -0.102      -0.043
# is_owner_change_2009_2017:jahr_2020     0.0460      0.031      1.495      0.135      -0.014       0.106
# ==============================================================================
# Omnibus:                     1483.860   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2373.764
# Skew:                           1.266   Prob(JB):                         0.00
# Kurtosis:                       3.450   Cond. No.                         6.35
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for energy_consumption in the period 2009-2017:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     energy_consumption   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     10.95
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           3.55e-07
# Time:                        18:13:51   Log-Likelihood:                -9852.8
# No. Observations:                8616   AIC:                         1.971e+04
# Df Residuals:                    8612   BIC:                         1.974e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.6106      0.013     47.864      0.000       0.586       0.636
# is_owner_change_2009_2017               0.0290      0.026      1.111      0.266      -0.022       0.080
# jahr_2020                              -0.0927      0.019     -4.933      0.000      -0.129      -0.056
# is_owner_change_2009_2017:jahr_2020     0.0258      0.039      0.668      0.504      -0.050       0.102
# ==============================================================================
# Omnibus:                     1428.723   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1262.390
# Skew:                           0.855   Prob(JB):                    7.51e-275
# Kurtosis:                       2.232   Cond. No.                         6.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for material_use in the period 2009-2017:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           material_use   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     49.12
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           1.83e-31
# Time:                        18:13:52   Log-Likelihood:                -9235.0
# No. Observations:                8572   AIC:                         1.848e+04
# Df Residuals:                    8568   BIC:                         1.851e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.5412      0.012     45.305      0.000       0.518       0.565
# is_owner_change_2009_2017               0.0272      0.025      1.110      0.267      -0.021       0.075
# jahr_2020                              -0.1884      0.018    -10.688      0.000      -0.223      -0.154
# is_owner_change_2009_2017:jahr_2020     0.0169      0.036      0.466      0.641      -0.054       0.088
# ==============================================================================
# Omnibus:                     1231.470   Durbin-Watson:                   1.993
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1843.748
# Skew:                           1.133   Prob(JB):                         0.00
# Kurtosis:                       2.843   Cond. No.                         6.36
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for emissions_CO2 in the period 2009-2017:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          emissions_CO2   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     11.91
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           8.86e-08
# Time:                        18:13:52   Log-Likelihood:                -9394.1
# No. Observations:                8558   AIC:                         1.880e+04
# Df Residuals:                    8554   BIC:                         1.882e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.5037      0.012     41.173      0.000       0.480       0.528
# is_owner_change_2009_2017               0.0085      0.025      0.339      0.735      -0.040       0.057
# jahr_2020                              -0.0965      0.018     -5.359      0.000      -0.132      -0.061
# is_owner_change_2009_2017:jahr_2020     0.0865      0.037      2.338      0.019       0.014       0.159
# ==============================================================================
# Omnibus:                     1283.619   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1959.266
# Skew:                           1.170   Prob(JB):                         0.00
# Kurtosis:                       2.863   Cond. No.                         6.35
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for emissions_other in the period 2009-2017:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        emissions_other   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     21.59
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           6.33e-14
# Time:                        18:13:53   Log-Likelihood:                -8154.7
# No. Observations:                8504   AIC:                         1.632e+04
# Df Residuals:                    8500   BIC:                         1.635e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.3648      0.011     34.156      0.000       0.344       0.386
# is_owner_change_2009_2017               0.0045      0.022      0.207      0.836      -0.038       0.047
# jahr_2020                              -0.1182      0.016     -7.519      0.000      -0.149      -0.087
# is_owner_change_2009_2017:jahr_2020     0.0673      0.032      2.081      0.037       0.004       0.131
# ==============================================================================
# Omnibus:                     2469.431   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5326.814
# Skew:                           1.748   Prob(JB):                         0.00
# Kurtosis:                       4.676   Cond. No.                         6.35
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for hazardous_material in the period 2009-2017:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     hazardous_material   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     29.91
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           3.16e-19
# Time:                        18:13:53   Log-Likelihood:                -7914.0
# No. Observations:                8459   AIC:                         1.584e+04
# Df Residuals:                    8455   BIC:                         1.586e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.3603      0.010     34.499      0.000       0.340       0.381
# is_owner_change_2009_2017              -0.0016      0.021     -0.076      0.939      -0.044       0.040
# jahr_2020                              -0.1272      0.015     -8.257      0.000      -0.157      -0.097
# is_owner_change_2009_2017:jahr_2020    -0.0012      0.032     -0.037      0.971      -0.063       0.061
# ==============================================================================
# Omnibus:                     2632.450   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6058.332
# Skew:                           1.822   Prob(JB):                         0.00
# Kurtosis:                       4.976   Cond. No.                         6.35
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for recycling in the period 2009-2017:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              recycling   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     35.32
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           1.13e-22
# Time:                        18:13:53   Log-Likelihood:                -9393.1
# No. Observations:                8493   AIC:                         1.879e+04
# Df Residuals:                    8489   BIC:                         1.882e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.5616      0.012     45.577      0.000       0.537       0.586
# is_owner_change_2009_2017              -0.0226      0.025     -0.894      0.372      -0.072       0.027
# jahr_2020                              -0.1725      0.018     -9.461      0.000      -0.208      -0.137
# is_owner_change_2009_2017:jahr_2020     0.0397      0.038      1.057      0.290      -0.034       0.113
# ==============================================================================
# Omnibus:                     1209.631   Durbin-Watson:                   1.926
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1775.412
# Skew:                           1.112   Prob(JB):                         0.00
# Kurtosis:                       2.739   Cond. No.                         6.34
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Regression with `bges` as control variable, mergers within 2009-2017 period

# %%
#Loop over all possible dependent variables
for y in dependent_variables:
    # Filter the data for the relevant years
    df_did = df_merged_companies[(df_merged_companies["jahr"] == 2008) | (df_merged_companies["jahr"] == 2020)]
    df_did = df_did[["companyid", "jahr", y, "is_owner_change_2009_2017", "bges"]]
    df_did["jahr_2020"] = np.where(df_did["jahr"] == 2020, 1, 0)
    df_did["is_owner_change_2009_2017"] = np.where(df_did["is_owner_change_2009_2017"] == True, 1, 0)

    # Set up the difference-in-differences model
    model_did = smf.ols(formula=y + ' ~ is_owner_change_2009_2017 + jahr_2020 + is_owner_change_2009_2017:jahr_2020 + bges', data=df_did)

    # Fit the model
    results_did = model_did.fit()

    # Print the model summary
    print("Regression results for " + y + " in the period 2009-2017, with bges (# of employees) as a control:\n")
    print(results_did.summary())
    print("\n\n")
# Out:
# Regression results for oekpz_avg in the period 2009-2017, with bges (# of employees) as a control:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              oekpz_avg   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     46.87
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           4.93e-39
# Time:                        18:13:54   Log-Likelihood:                -6668.1
# No. Observations:                8625   AIC:                         1.335e+04
# Df Residuals:                    8620   BIC:                         1.338e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.4501      0.009     51.310      0.000       0.433       0.467
# is_owner_change_2009_2017               0.0024      0.018      0.133      0.894      -0.033       0.038
# jahr_2020                              -0.1119      0.013     -8.631      0.000      -0.137      -0.087
# is_owner_change_2009_2017:jahr_2020     0.0228      0.027      0.851      0.395      -0.030       0.075
# bges                                 1.093e-05   1.13e-06      9.704      0.000    8.72e-06    1.31e-05
# ==============================================================================
# Omnibus:                     1737.615   Durbin-Watson:                   1.949
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2997.995
# Skew:                           1.340   Prob(JB):                         0.00
# Kurtosis:                       4.075   Cond. No.                     2.76e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.76e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Regression results for oekpd_avg in the period 2009-2017, with bges (# of employees) as a control:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              oekpd_avg   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     25.71
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           3.28e-21
# Time:                        18:13:54   Log-Likelihood:                -7765.2
# No. Observations:                8528   AIC:                         1.554e+04
# Df Residuals:                    8523   BIC:                         1.558e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.4471      0.010     44.241      0.000       0.427       0.467
# is_owner_change_2009_2017               0.0008      0.021      0.040      0.968      -0.040       0.041
# jahr_2020                              -0.0705      0.015     -4.713      0.000      -0.100      -0.041
# is_owner_change_2009_2017:jahr_2020     0.0429      0.031      1.391      0.164      -0.018       0.103
# bges                                 1.131e-05   1.29e-06      8.740      0.000    8.77e-06    1.38e-05
# ==============================================================================
# Omnibus:                     1482.705   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2378.560
# Skew:                           1.270   Prob(JB):                         0.00
# Kurtosis:                       3.487   Cond. No.                     2.77e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.77e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Regression results for energy_consumption in the period 2009-2017, with bges (# of employees) as a control:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     energy_consumption   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     23.19
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           4.36e-19
# Time:                        18:13:55   Log-Likelihood:                -9728.0
# No. Observations:                8524   AIC:                         1.947e+04
# Df Residuals:                    8519   BIC:                         1.950e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.6039      0.013     47.296      0.000       0.579       0.629
# is_owner_change_2009_2017               0.0314      0.026      1.203      0.229      -0.020       0.083
# jahr_2020                              -0.0886      0.019     -4.698      0.000      -0.126      -0.052
# is_owner_change_2009_2017:jahr_2020     0.0206      0.039      0.531      0.596      -0.056       0.097
# bges                                  1.27e-05   1.63e-06      7.801      0.000    9.51e-06    1.59e-05
# ==============================================================================
# Omnibus:                     1377.867   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1243.537
# Skew:                           0.856   Prob(JB):                    9.32e-271
# Kurtosis:                       2.245   Cond. No.                     2.77e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.77e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Regression results for material_use in the period 2009-2017, with bges (# of employees) as a control:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           material_use   R-squared:                       0.024
# Model:                            OLS   Adj. R-squared:                  0.023
# Method:                 Least Squares   F-statistic:                     51.71
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           4.32e-43
# Time:                        18:13:55   Log-Likelihood:                -9121.3
# No. Observations:                8481   AIC:                         1.825e+04
# Df Residuals:                    8476   BIC:                         1.829e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.5349      0.012     44.715      0.000       0.511       0.558
# is_owner_change_2009_2017               0.0289      0.025      1.179      0.238      -0.019       0.077
# jahr_2020                              -0.1848      0.018    -10.442      0.000      -0.220      -0.150
# is_owner_change_2009_2017:jahr_2020     0.0140      0.036      0.382      0.702      -0.058       0.085
# bges                                 1.233e-05   1.57e-06      7.849      0.000    9.25e-06    1.54e-05
# ==============================================================================
# Omnibus:                     1213.414   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1816.151
# Skew:                           1.131   Prob(JB):                         0.00
# Kurtosis:                       2.858   Cond. No.                     2.69e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.69e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Regression results for emissions_CO2 in the period 2009-2017, with bges (# of employees) as a control:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          emissions_CO2   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     28.81
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           8.11e-24
# Time:                        18:13:55   Log-Likelihood:                -9259.7
# No. Observations:                8467   AIC:                         1.853e+04
# Df Residuals:                    8462   BIC:                         1.856e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.4964      0.012     40.614      0.000       0.472       0.520
# is_owner_change_2009_2017               0.0101      0.025      0.407      0.684      -0.039       0.059
# jahr_2020                              -0.0923      0.018     -5.114      0.000      -0.128      -0.057
# is_owner_change_2009_2017:jahr_2020     0.0791      0.037      2.131      0.033       0.006       0.152
# bges                                 1.423e-05   1.58e-06      8.982      0.000    1.11e-05    1.73e-05
# ==============================================================================
# Omnibus:                     1264.206   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1929.914
# Skew:                           1.168   Prob(JB):                         0.00
# Kurtosis:                       2.892   Cond. No.                     2.72e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.72e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Regression results for emissions_other in the period 2009-2017, with bges (# of employees) as a control:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        emissions_other   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     35.28
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           2.88e-29
# Time:                        18:13:56   Log-Likelihood:                -8038.9
# No. Observations:                8414   AIC:                         1.609e+04
# Df Residuals:                    8409   BIC:                         1.612e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.3587      0.011     33.598      0.000       0.338       0.380
# is_owner_change_2009_2017               0.0042      0.022      0.193      0.847      -0.038       0.047
# jahr_2020                              -0.1159      0.016     -7.353      0.000      -0.147      -0.085
# is_owner_change_2009_2017:jahr_2020     0.0677      0.032      2.085      0.037       0.004       0.131
# bges                                 1.207e-05   1.38e-06      8.743      0.000    9.36e-06    1.48e-05
# ==============================================================================
# Omnibus:                     2447.853   Durbin-Watson:                   1.971
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5297.417
# Skew:                           1.747   Prob(JB):                         0.00
# Kurtosis:                       4.704   Cond. No.                     2.73e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.73e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Regression results for hazardous_material in the period 2009-2017, with bges (# of employees) as a control:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     hazardous_material   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     37.92
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           1.71e-31
# Time:                        18:13:56   Log-Likelihood:                -7805.8
# No. Observations:                8373   AIC:                         1.562e+04
# Df Residuals:                    8368   BIC:                         1.566e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.3543      0.010     33.938      0.000       0.334       0.375
# is_owner_change_2009_2017              -0.0017      0.021     -0.081      0.936      -0.044       0.040
# jahr_2020                              -0.1237      0.015     -8.008      0.000      -0.154      -0.093
# is_owner_change_2009_2017:jahr_2020    -0.0055      0.032     -0.173      0.863      -0.068       0.057
# bges                                 1.082e-05   1.36e-06      7.937      0.000    8.15e-06    1.35e-05
# ==============================================================================
# Omnibus:                     2605.664   Durbin-Watson:                   1.904
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6007.740
# Skew:                           1.819   Prob(JB):                         0.00
# Kurtosis:                       4.995   Cond. No.                     2.71e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.71e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
#
#
# Regression results for recycling in the period 2009-2017, with bges (# of employees) as a control:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              recycling   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                  0.016
# Method:                 Least Squares   F-statistic:                     35.96
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           7.69e-30
# Time:                        18:13:57   Log-Likelihood:                -9279.1
# No. Observations:                8404   AIC:                         1.857e+04
# Df Residuals:                    8399   BIC:                         1.860e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# =======================================================================================================
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# Intercept                               0.5562      0.012     45.086      0.000       0.532       0.580
# is_owner_change_2009_2017              -0.0231      0.025     -0.915      0.360      -0.073       0.026
# jahr_2020                              -0.1690      0.018     -9.232      0.000      -0.205      -0.133
# is_owner_change_2009_2017:jahr_2020     0.0349      0.038      0.924      0.355      -0.039       0.109
# bges                                 1.019e-05   1.63e-06      6.261      0.000       7e-06    1.34e-05
# ==============================================================================
# Omnibus:                     1196.184   Durbin-Watson:                   1.927
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1758.685
# Skew:                           1.113   Prob(JB):                         0.00
# Kurtosis:                       2.748   Cond. No.                     2.69e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.69e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# Regression with `bges` and `branche` as control variables, mergers within 2009-2017 period

# %%
#Loop over all possible dependent variables
for y in dependent_variables:
    # Filter the data for the relevant years
    df_did = df_merged_companies[(df_merged_companies["jahr"] == 2008) | (df_merged_companies["jahr"] == 2020)]
    df_did = df_did[["companyid", "jahr", y, "is_owner_change_2009_2017", "bges", "branche"]]
    df_did["jahr_2020"] = np.where(df_did["jahr"] == 2020, 1, 0)
    df_did["is_owner_change_2009_2017"] = np.where(df_did["is_owner_change_2009_2017"] == True, 1, 0)

    # Set up the difference-in-differences model
    model_did = smf.ols(formula=y + ' ~ is_owner_change_2009_2017 + jahr_2020 + is_owner_change_2009_2017:jahr_2020 + bges + C(branche)', data=df_did)

    # Fit the model
    results_did = model_did.fit()

    # Print the model summary
    print("Regression results for " + y + " in the period 2009-2017, with bges (# of employees) and branche (industry) as controls:\n")
    print(results_did.summary())
# Out:
# Regression results for oekpz_avg in the period 2009-2017, with bges (# of employees) and branche (industry) as controls:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              oekpz_avg   R-squared:                       0.072
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     26.21
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):          9.60e-113
# Time:                        18:13:57   Log-Likelihood:                -6074.0
# No. Observations:                8104   AIC:                         1.220e+04
# Df Residuals:                    8079   BIC:                         1.237e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# =======================================================================================================================
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                               0.5939      0.030     19.502      0.000       0.534       0.654
# C(branche)[T.EDV/Telekommunikation]                    -0.3781      0.041     -9.259      0.000      -0.458      -0.298
# C(branche)[T.Elektroindustrie]                         -0.0590      0.037     -1.612      0.107      -0.131       0.013
# C(branche)[T.Energie/Bergbau/Mineralöl]                -0.0950      0.040     -2.352      0.019      -0.174      -0.016
# C(branche)[T.Fahrzeugbau]                               0.0828      0.043      1.916      0.055      -0.002       0.167
# C(branche)[T.Finanzdienstleistungen]                   -0.3491      0.049     -7.068      0.000      -0.446      -0.252
# C(branche)[T.Glas/Keramik/Steinwaren]                  -0.0124      0.046     -0.268      0.789      -0.103       0.078
# C(branche)[T.Großhandel]                               -0.2594      0.042     -6.124      0.000      -0.342      -0.176
# C(branche)[T.Gummi-/Kunststoffverarbeitung]            -0.0683      0.042     -1.615      0.106      -0.151       0.015
# C(branche)[T.Holz/Papier]                              -0.0891      0.042     -2.125      0.034      -0.171      -0.007
# C(branche)[T.Maschinenbau]                             -0.0297      0.038     -0.775      0.439      -0.105       0.045
# C(branche)[T.Mediendienstleistungen]                   -0.2530      0.039     -6.550      0.000      -0.329      -0.177
# C(branche)[T.Metallerzeugung/-bearbeitung]             -0.0469      0.036     -1.290      0.197      -0.118       0.024
# C(branche)[T.Möbel/Spielw./Medizintechn./Reparatur]    -0.1830      0.037     -4.978      0.000      -0.255      -0.111
# C(branche)[T.Nahrungsmittel/Getränke/Tabak]            -0.0914      0.040     -2.306      0.021      -0.169      -0.014
# C(branche)[T.Technische/FuE-Dienstleistungen]          -0.2704      0.039     -6.909      0.000      -0.347      -0.194
# C(branche)[T.Textil/Bekleidung/Leder]                  -0.1677      0.042     -4.020      0.000      -0.249      -0.086
# C(branche)[T.Transport/Post]                           -0.1008      0.035     -2.857      0.004      -0.170      -0.032
# C(branche)[T.Unternehmensberatung/Werbung]             -0.4066      0.041     -9.838      0.000      -0.488      -0.326
# C(branche)[T.Unternehmensdienste]                      -0.2431      0.038     -6.389      0.000      -0.318      -0.168
# C(branche)[T.Wasser/Entsorgung/Recycling]              -0.0583      0.040     -1.456      0.145      -0.137       0.020
# is_owner_change_2009_2017                              -0.0016      0.018     -0.089      0.929      -0.037       0.034
# jahr_2020                                              -0.1040      0.013     -7.903      0.000      -0.130      -0.078
# is_owner_change_2009_2017:jahr_2020                     0.0197      0.027      0.734      0.463      -0.033       0.072
# bges                                                 1.002e-05   1.11e-06      9.063      0.000    7.85e-06    1.22e-05
# ==============================================================================
# Omnibus:                     1534.623   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2579.654
# Skew:                           1.273   Prob(JB):                         0.00
# Kurtosis:                       4.074   Cond. No.                     1.26e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Regression results for oekpd_avg in the period 2009-2017, with bges (# of employees) and branche (industry) as controls:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              oekpd_avg   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     16.65
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           6.84e-68
# Time:                        18:13:57   Log-Likelihood:                -7169.9
# No. Observations:                8007   AIC:                         1.439e+04
# Df Residuals:                    7982   BIC:                         1.456e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# =======================================================================================================================
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                               0.5127      0.036     14.366      0.000       0.443       0.583
# C(branche)[T.EDV/Telekommunikation]                    -0.2584      0.048     -5.421      0.000      -0.352      -0.165
# C(branche)[T.Elektroindustrie]                          0.0543      0.043      1.270      0.204      -0.030       0.138
# C(branche)[T.Energie/Bergbau/Mineralöl]                -0.0447      0.047     -0.947      0.344      -0.137       0.048
# C(branche)[T.Fahrzeugbau]                               0.1134      0.050      2.246      0.025       0.014       0.212
# C(branche)[T.Finanzdienstleistungen]                   -0.3140      0.058     -5.435      0.000      -0.427      -0.201
# C(branche)[T.Glas/Keramik/Steinwaren]                   0.0245      0.054      0.451      0.652      -0.082       0.131
# C(branche)[T.Großhandel]                               -0.1549      0.050     -3.126      0.002      -0.252      -0.058
# C(branche)[T.Gummi-/Kunststoffverarbeitung]             0.0128      0.049      0.258      0.796      -0.084       0.109
# C(branche)[T.Holz/Papier]                              -0.0368      0.049     -0.752      0.452      -0.133       0.059
# C(branche)[T.Maschinenbau]                              0.1411      0.045      3.154      0.002       0.053       0.229
# C(branche)[T.Mediendienstleistungen]                   -0.1917      0.045     -4.243      0.000      -0.280      -0.103
# C(branche)[T.Metallerzeugung/-bearbeitung]             -0.0376      0.043     -0.883      0.377      -0.121       0.046
# C(branche)[T.Möbel/Spielw./Medizintechn./Reparatur]    -0.1224      0.043     -2.849      0.004      -0.207      -0.038
# C(branche)[T.Nahrungsmittel/Getränke/Tabak]            -0.0490      0.046     -1.058      0.290      -0.140       0.042
# C(branche)[T.Technische/FuE-Dienstleistungen]          -0.0926      0.046     -2.027      0.043      -0.182      -0.003
# C(branche)[T.Textil/Bekleidung/Leder]                  -0.0951      0.049     -1.954      0.051      -0.191       0.000
# C(branche)[T.Transport/Post]                           -0.0274      0.041     -0.662      0.508      -0.109       0.054
# C(branche)[T.Unternehmensberatung/Werbung]             -0.3227      0.048     -6.700      0.000      -0.417      -0.228
# C(branche)[T.Unternehmensdienste]                      -0.1665      0.044     -3.746      0.000      -0.254      -0.079
# C(branche)[T.Wasser/Entsorgung/Recycling]               0.0357      0.047      0.761      0.446      -0.056       0.128
# is_owner_change_2009_2017                              -0.0044      0.021     -0.208      0.836      -0.045       0.037
# jahr_2020                                              -0.0564      0.015     -3.681      0.000      -0.086      -0.026
# is_owner_change_2009_2017:jahr_2020                     0.0371      0.031      1.187      0.235      -0.024       0.098
# bges                                                 1.054e-05   1.28e-06      8.224      0.000    8.03e-06    1.31e-05
# ==============================================================================
# Omnibus:                     1302.084   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2027.645
# Skew:                           1.209   Prob(JB):                         0.00
# Kurtosis:                       3.479   Cond. No.                     1.28e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.28e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Regression results for energy_consumption in the period 2009-2017, with bges (# of employees) and branche (industry) as controls:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     energy_consumption   R-squared:                       0.061
# Model:                            OLS   Adj. R-squared:                  0.058
# Method:                 Least Squares   F-statistic:                     21.70
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           1.35e-91
# Time:                        18:13:58   Log-Likelihood:                -8965.8
# No. Observations:                8012   AIC:                         1.798e+04
# Df Residuals:                    7987   BIC:                         1.816e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# =======================================================================================================================
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                               0.7842      0.044     17.683      0.000       0.697       0.871
# C(branche)[T.EDV/Telekommunikation]                    -0.4426      0.059     -7.458      0.000      -0.559      -0.326
# C(branche)[T.Elektroindustrie]                         -0.0228      0.053     -0.428      0.668      -0.127       0.082
# C(branche)[T.Energie/Bergbau/Mineralöl]                -0.1598      0.059     -2.716      0.007      -0.275      -0.044
# C(branche)[T.Fahrzeugbau]                               0.0989      0.063      1.568      0.117      -0.025       0.222
# C(branche)[T.Finanzdienstleistungen]                   -0.4615      0.072     -6.427      0.000      -0.602      -0.321
# C(branche)[T.Glas/Keramik/Steinwaren]                  -0.0212      0.067     -0.315      0.752      -0.153       0.111
# C(branche)[T.Großhandel]                               -0.3885      0.062     -6.295      0.000      -0.509      -0.268
# C(branche)[T.Gummi-/Kunststoffverarbeitung]             0.0094      0.062      0.153      0.878      -0.111       0.130
# C(branche)[T.Holz/Papier]                              -0.0858      0.061     -1.404      0.160      -0.205       0.034
# C(branche)[T.Maschinenbau]                             -0.0318      0.056     -0.570      0.569      -0.141       0.078
# C(branche)[T.Mediendienstleistungen]                   -0.3227      0.056     -5.739      0.000      -0.433      -0.212
# C(branche)[T.Metallerzeugung/-bearbeitung]             -0.0105      0.053     -0.198      0.843      -0.114       0.093
# C(branche)[T.Möbel/Spielw./Medizintechn./Reparatur]    -0.2337      0.054     -4.368      0.000      -0.339      -0.129
# C(branche)[T.Nahrungsmittel/Getränke/Tabak]             0.0245      0.058      0.425      0.671      -0.089       0.138
# C(branche)[T.Technische/FuE-Dienstleistungen]          -0.3518      0.057     -6.178      0.000      -0.463      -0.240
# C(branche)[T.Textil/Bekleidung/Leder]                  -0.1913      0.061     -3.148      0.002      -0.310      -0.072
# C(branche)[T.Transport/Post]                           -0.1691      0.051     -3.284      0.001      -0.270      -0.068
# C(branche)[T.Unternehmensberatung/Werbung]             -0.5349      0.060     -8.887      0.000      -0.653      -0.417
# C(branche)[T.Unternehmensdienste]                      -0.3906      0.055     -7.063      0.000      -0.499      -0.282
# C(branche)[T.Wasser/Entsorgung/Recycling]              -0.1841      0.058     -3.148      0.002      -0.299      -0.069
# is_owner_change_2009_2017                               0.0267      0.026      1.018      0.309      -0.025       0.078
# jahr_2020                                              -0.0727      0.019     -3.798      0.000      -0.110      -0.035
# is_owner_change_2009_2017:jahr_2020                     0.0151      0.039      0.386      0.699      -0.062       0.092
# bges                                                 1.153e-05    1.6e-06      7.204      0.000     8.4e-06    1.47e-05
# ==============================================================================
# Omnibus:                     1061.495   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              970.709
# Skew:                           0.777   Prob(JB):                    1.63e-211
# Kurtosis:                       2.300   Cond. No.                     1.27e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.27e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Regression results for material_use in the period 2009-2017, with bges (# of employees) and branche (industry) as controls:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           material_use   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     22.58
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           1.13e-95
# Time:                        18:13:58   Log-Likelihood:                -8450.5
# No. Observations:                7966   AIC:                         1.695e+04
# Df Residuals:                    7941   BIC:                         1.713e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# =======================================================================================================================
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                               0.6920      0.042     16.377      0.000       0.609       0.775
# C(branche)[T.EDV/Telekommunikation]                    -0.3935      0.056     -6.974      0.000      -0.504      -0.283
# C(branche)[T.Elektroindustrie]                          0.0034      0.051      0.067      0.947      -0.096       0.103
# C(branche)[T.Energie/Bergbau/Mineralöl]                -0.2535      0.056     -4.520      0.000      -0.363      -0.144
# C(branche)[T.Fahrzeugbau]                               0.1600      0.060      2.670      0.008       0.043       0.277
# C(branche)[T.Finanzdienstleistungen]                   -0.1809      0.068     -2.665      0.008      -0.314      -0.048
# C(branche)[T.Glas/Keramik/Steinwaren]                   0.0693      0.064      1.081      0.280      -0.056       0.195
# C(branche)[T.Großhandel]                               -0.3545      0.059     -6.058      0.000      -0.469      -0.240
# C(branche)[T.Gummi-/Kunststoffverarbeitung]             0.0494      0.058      0.844      0.398      -0.065       0.164
# C(branche)[T.Holz/Papier]                              -0.1050      0.058     -1.815      0.070      -0.218       0.008
# C(branche)[T.Maschinenbau]                              0.0180      0.053      0.340      0.734      -0.086       0.122
# C(branche)[T.Mediendienstleistungen]                   -0.2068      0.053     -3.874      0.000      -0.311      -0.102
# C(branche)[T.Metallerzeugung/-bearbeitung]             -0.0022      0.050     -0.044      0.965      -0.101       0.096
# C(branche)[T.Möbel/Spielw./Medizintechn./Reparatur]    -0.1827      0.051     -3.592      0.000      -0.282      -0.083
# C(branche)[T.Nahrungsmittel/Getränke/Tabak]            -0.0993      0.055     -1.811      0.070      -0.207       0.008
# C(branche)[T.Technische/FuE-Dienstleistungen]          -0.2726      0.054     -5.040      0.000      -0.379      -0.167
# C(branche)[T.Textil/Bekleidung/Leder]                  -0.1096      0.058     -1.902      0.057      -0.223       0.003
# C(branche)[T.Transport/Post]                           -0.2442      0.049     -4.983      0.000      -0.340      -0.148
# C(branche)[T.Unternehmensberatung/Werbung]             -0.3563      0.057     -6.253      0.000      -0.468      -0.245
# C(branche)[T.Unternehmensdienste]                      -0.2067      0.053     -3.934      0.000      -0.310      -0.104
# C(branche)[T.Wasser/Entsorgung/Recycling]              -0.2832      0.056     -5.096      0.000      -0.392      -0.174
# is_owner_change_2009_2017                               0.0038      0.025      0.154      0.877      -0.045       0.053
# jahr_2020                                              -0.1815      0.018    -10.014      0.000      -0.217      -0.146
# is_owner_change_2009_2017:jahr_2020                     0.0221      0.037      0.598      0.550      -0.050       0.095
# bges                                                 1.105e-05   1.56e-06      7.099      0.000       8e-06    1.41e-05
# ==============================================================================
# Omnibus:                     1033.367   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1491.943
# Skew:                           1.058   Prob(JB):                         0.00
# Kurtosis:                       2.873   Cond. No.                     1.25e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.25e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Regression results for emissions_CO2 in the period 2009-2017, with bges (# of employees) and branche (industry) as controls:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          emissions_CO2   R-squared:                       0.057
# Model:                            OLS   Adj. R-squared:                  0.054
# Method:                 Least Squares   F-statistic:                     20.04
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           8.44e-84
# Time:                        18:13:59   Log-Likelihood:                -8528.7
# No. Observations:                7950   AIC:                         1.711e+04
# Df Residuals:                    7925   BIC:                         1.728e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# =======================================================================================================================
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                               0.5997      0.043     14.046      0.000       0.516       0.683
# C(branche)[T.EDV/Telekommunikation]                    -0.3976      0.057     -6.955      0.000      -0.510      -0.286
# C(branche)[T.Elektroindustrie]                         -0.0661      0.051     -1.287      0.198      -0.167       0.035
# C(branche)[T.Energie/Bergbau/Mineralöl]                 0.0561      0.056      0.993      0.321      -0.055       0.167
# C(branche)[T.Fahrzeugbau]                               0.0630      0.060      1.042      0.297      -0.056       0.182
# C(branche)[T.Finanzdienstleistungen]                   -0.3081      0.069     -4.472      0.000      -0.443      -0.173
# C(branche)[T.Glas/Keramik/Steinwaren]                   0.0077      0.065      0.119      0.905      -0.119       0.135
# C(branche)[T.Großhandel]                               -0.2492      0.059     -4.204      0.000      -0.365      -0.133
# C(branche)[T.Gummi-/Kunststoffverarbeitung]            -0.0645      0.059     -1.089      0.276      -0.181       0.052
# C(branche)[T.Holz/Papier]                              -0.0543      0.059     -0.925      0.355      -0.169       0.061
# C(branche)[T.Maschinenbau]                             -0.0485      0.054     -0.904      0.366      -0.154       0.057
# C(branche)[T.Mediendienstleistungen]                   -0.2696      0.054     -4.991      0.000      -0.375      -0.164
# C(branche)[T.Metallerzeugung/-bearbeitung]             -0.0074      0.051     -0.145      0.885      -0.107       0.092
# C(branche)[T.Möbel/Spielw./Medizintechn./Reparatur]    -0.2183      0.051     -4.241      0.000      -0.319      -0.117
# C(branche)[T.Nahrungsmittel/Getränke/Tabak]            -0.0220      0.055     -0.398      0.691      -0.131       0.086
# C(branche)[T.Technische/FuE-Dienstleistungen]          -0.2407      0.055     -4.396      0.000      -0.348      -0.133
# C(branche)[T.Textil/Bekleidung/Leder]                  -0.2180      0.058     -3.732      0.000      -0.333      -0.103
# C(branche)[T.Transport/Post]                            0.1277      0.049      2.583      0.010       0.031       0.225
# C(branche)[T.Unternehmensberatung/Werbung]             -0.4135      0.058     -7.163      0.000      -0.527      -0.300
# C(branche)[T.Unternehmensdienste]                      -0.2404      0.053     -4.519      0.000      -0.345      -0.136
# C(branche)[T.Wasser/Entsorgung/Recycling]               0.0059      0.056      0.106      0.916      -0.104       0.116
# is_owner_change_2009_2017                               0.0186      0.025      0.741      0.459      -0.031       0.068
# jahr_2020                                              -0.0770      0.018     -4.191      0.000      -0.113      -0.041
# is_owner_change_2009_2017:jahr_2020                     0.0695      0.037      1.856      0.063      -0.004       0.143
# bges                                                 1.345e-05   1.56e-06      8.624      0.000    1.04e-05    1.65e-05
# ==============================================================================
# Omnibus:                     1061.930   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1550.123
# Skew:                           1.080   Prob(JB):                         0.00
# Kurtosis:                       2.877   Cond. No.                     1.26e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Regression results for emissions_other in the period 2009-2017, with bges (# of employees) and branche (industry) as controls:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        emissions_other   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.055
# Method:                 Least Squares   F-statistic:                     20.28
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           6.49e-85
# Time:                        18:13:59   Log-Likelihood:                -7422.1
# No. Observations:                7902   AIC:                         1.489e+04
# Df Residuals:                    7877   BIC:                         1.507e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# =======================================================================================================================
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                               0.3753      0.037     10.012      0.000       0.302       0.449
# C(branche)[T.EDV/Telekommunikation]                    -0.2367      0.050     -4.724      0.000      -0.335      -0.138
# C(branche)[T.Elektroindustrie]                         -0.0357      0.045     -0.792      0.429      -0.124       0.053
# C(branche)[T.Energie/Bergbau/Mineralöl]                 0.1313      0.050      2.652      0.008       0.034       0.228
# C(branche)[T.Fahrzeugbau]                               0.1733      0.053      3.263      0.001       0.069       0.277
# C(branche)[T.Finanzdienstleistungen]                   -0.2117      0.060     -3.507      0.000      -0.330      -0.093
# C(branche)[T.Glas/Keramik/Steinwaren]                   0.1677      0.057      2.949      0.003       0.056       0.279
# C(branche)[T.Großhandel]                               -0.1209      0.052     -2.327      0.020      -0.223      -0.019
# C(branche)[T.Gummi-/Kunststoffverarbeitung]            -0.0612      0.052     -1.181      0.238      -0.163       0.040
# C(branche)[T.Holz/Papier]                               0.0147      0.051      0.285      0.775      -0.086       0.116
# C(branche)[T.Maschinenbau]                              0.0560      0.047      1.192      0.233      -0.036       0.148
# C(branche)[T.Mediendienstleistungen]                   -0.1687      0.047     -3.558      0.000      -0.262      -0.076
# C(branche)[T.Metallerzeugung/-bearbeitung]              0.0887      0.045      1.989      0.047       0.001       0.176
# C(branche)[T.Möbel/Spielw./Medizintechn./Reparatur]    -0.0745      0.045     -1.649      0.099      -0.163       0.014
# C(branche)[T.Nahrungsmittel/Getränke/Tabak]             0.0062      0.049      0.128      0.898      -0.089       0.102
# C(branche)[T.Technische/FuE-Dienstleistungen]          -0.1170      0.048     -2.430      0.015      -0.211      -0.023
# C(branche)[T.Textil/Bekleidung/Leder]                  -0.0837      0.051     -1.630      0.103      -0.184       0.017
# C(branche)[T.Transport/Post]                            0.1859      0.043      4.280      0.000       0.101       0.271
# C(branche)[T.Unternehmensberatung/Werbung]             -0.2347      0.051     -4.637      0.000      -0.334      -0.135
# C(branche)[T.Unternehmensdienste]                      -0.1390      0.047     -2.974      0.003      -0.231      -0.047
# C(branche)[T.Wasser/Entsorgung/Recycling]               0.1213      0.049      2.459      0.014       0.025       0.218
# is_owner_change_2009_2017                               0.0077      0.022      0.347      0.728      -0.036       0.051
# jahr_2020                                              -0.1121      0.016     -6.954      0.000      -0.144      -0.081
# is_owner_change_2009_2017:jahr_2020                     0.0673      0.033      2.048      0.041       0.003       0.132
# bges                                                 1.132e-05   1.36e-06      8.292      0.000    8.64e-06     1.4e-05
# ==============================================================================
# Omnibus:                     2077.971   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4190.811
# Skew:                           1.619   Prob(JB):                         0.00
# Kurtosis:                       4.498   Cond. No.                     1.26e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.26e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Regression results for hazardous_material in the period 2009-2017, with bges (# of employees) and branche (industry) as controls:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     hazardous_material   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.068
# Method:                 Least Squares   F-statistic:                     24.80
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):          5.34e-106
# Time:                        18:14:00   Log-Likelihood:                -7167.2
# No. Observations:                7869   AIC:                         1.438e+04
# Df Residuals:                    7844   BIC:                         1.456e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# =======================================================================================================================
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                               0.6128      0.036     16.902      0.000       0.542       0.684
# C(branche)[T.EDV/Telekommunikation]                    -0.4890      0.049    -10.060      0.000      -0.584      -0.394
# C(branche)[T.Elektroindustrie]                         -0.0213      0.044     -0.489      0.625      -0.107       0.064
# C(branche)[T.Energie/Bergbau/Mineralöl]                -0.3216      0.048     -6.653      0.000      -0.416      -0.227
# C(branche)[T.Fahrzeugbau]                               0.0422      0.052      0.818      0.413      -0.059       0.143
# C(branche)[T.Finanzdienstleistungen]                   -0.5105      0.059     -8.701      0.000      -0.626      -0.396
# C(branche)[T.Glas/Keramik/Steinwaren]                  -0.2319      0.055     -4.198      0.000      -0.340      -0.124
# C(branche)[T.Großhandel]                               -0.3378      0.050     -6.712      0.000      -0.436      -0.239
# C(branche)[T.Gummi-/Kunststoffverarbeitung]            -0.1672      0.050     -3.327      0.001      -0.266      -0.069
# C(branche)[T.Holz/Papier]                              -0.2260      0.050     -4.534      0.000      -0.324      -0.128
# C(branche)[T.Maschinenbau]                             -0.0844      0.046     -1.848      0.065      -0.174       0.005
# C(branche)[T.Mediendienstleistungen]                   -0.2966      0.046     -6.455      0.000      -0.387      -0.207
# C(branche)[T.Metallerzeugung/-bearbeitung]             -0.1790      0.043     -4.140      0.000      -0.264      -0.094
# C(branche)[T.Möbel/Spielw./Medizintechn./Reparatur]    -0.2421      0.044     -5.525      0.000      -0.328      -0.156
# C(branche)[T.Nahrungsmittel/Getränke/Tabak]            -0.3472      0.047     -7.347      0.000      -0.440      -0.255
# C(branche)[T.Technische/FuE-Dienstleistungen]          -0.3623      0.047     -7.770      0.000      -0.454      -0.271
# C(branche)[T.Textil/Bekleidung/Leder]                  -0.2051      0.050     -4.121      0.000      -0.303      -0.108
# C(branche)[T.Transport/Post]                           -0.3659      0.042     -8.677      0.000      -0.449      -0.283
# C(branche)[T.Unternehmensberatung/Werbung]             -0.5059      0.049    -10.296      0.000      -0.602      -0.410
# C(branche)[T.Unternehmensdienste]                      -0.2734      0.045     -6.044      0.000      -0.362      -0.185
# C(branche)[T.Wasser/Entsorgung/Recycling]              -0.2841      0.048     -5.920      0.000      -0.378      -0.190
# is_owner_change_2009_2017                              -0.0237      0.021     -1.104      0.270      -0.066       0.018
# jahr_2020                                              -0.1169      0.016     -7.444      0.000      -0.148      -0.086
# is_owner_change_2009_2017:jahr_2020                    -0.0015      0.032     -0.048      0.962      -0.064       0.061
# bges                                                 9.681e-06   1.34e-06      7.219      0.000    7.05e-06    1.23e-05
# ==============================================================================
# Omnibus:                     2221.889   Durbin-Watson:                   1.933
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4794.103
# Skew:                           1.677   Prob(JB):                         0.00
# Kurtosis:                       4.835   Cond. No.                     1.24e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.24e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Regression results for recycling in the period 2009-2017, with bges (# of employees) and branche (industry) as controls:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              recycling   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     23.73
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):          4.84e-101
# Time:                        18:14:00   Log-Likelihood:                -8546.2
# No. Observations:                7894   AIC:                         1.714e+04
# Df Residuals:                    7869   BIC:                         1.732e+04
# Df Model:                          24
# Covariance Type:            nonrobust
# =======================================================================================================================
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                               0.7191      0.043     16.685      0.000       0.635       0.804
# C(branche)[T.EDV/Telekommunikation]                    -0.4389      0.058     -7.590      0.000      -0.552      -0.326
# C(branche)[T.Elektroindustrie]                         -0.0253      0.052     -0.488      0.626      -0.127       0.076
# C(branche)[T.Energie/Bergbau/Mineralöl]                -0.2884      0.057     -5.022      0.000      -0.401      -0.176
# C(branche)[T.Fahrzeugbau]                               0.0635      0.061      1.034      0.301      -0.057       0.184
# C(branche)[T.Finanzdienstleistungen]                   -0.4436      0.069     -6.387      0.000      -0.580      -0.307
# C(branche)[T.Glas/Keramik/Steinwaren]                   0.0015      0.065      0.023      0.982      -0.127       0.130
# C(branche)[T.Großhandel]                               -0.2974      0.060     -4.963      0.000      -0.415      -0.180
# C(branche)[T.Gummi-/Kunststoffverarbeitung]             0.0996      0.060      1.669      0.095      -0.017       0.217
# C(branche)[T.Holz/Papier]                              -0.0228      0.059     -0.384      0.701      -0.139       0.093
# C(branche)[T.Maschinenbau]                             -0.0330      0.054     -0.610      0.542      -0.139       0.073
# C(branche)[T.Mediendienstleistungen]                   -0.2044      0.055     -3.743      0.000      -0.312      -0.097
# C(branche)[T.Metallerzeugung/-bearbeitung]             -0.0958      0.051     -1.862      0.063      -0.197       0.005
# C(branche)[T.Möbel/Spielw./Medizintechn./Reparatur]    -0.1952      0.052     -3.748      0.000      -0.297      -0.093
# C(branche)[T.Nahrungsmittel/Getränke/Tabak]            -0.0294      0.056     -0.527      0.598      -0.139       0.080
# C(branche)[T.Technische/FuE-Dienstleistungen]          -0.3740      0.056     -6.736      0.000      -0.483      -0.265
# C(branche)[T.Textil/Bekleidung/Leder]                  -0.1394      0.059     -2.360      0.018      -0.255      -0.024
# C(branche)[T.Transport/Post]                           -0.2876      0.050     -5.743      0.000      -0.386      -0.189
# C(branche)[T.Unternehmensberatung/Werbung]             -0.4635      0.058     -7.949      0.000      -0.578      -0.349
# C(branche)[T.Unternehmensdienste]                      -0.2680      0.054     -4.989      0.000      -0.373      -0.163
# C(branche)[T.Wasser/Entsorgung/Recycling]               0.1232      0.057      2.171      0.030       0.012       0.234
# is_owner_change_2009_2017                              -0.0321      0.025     -1.263      0.207      -0.082       0.018
# jahr_2020                                              -0.1571      0.019     -8.438      0.000      -0.194      -0.121
# is_owner_change_2009_2017:jahr_2020                     0.0313      0.038      0.823      0.410      -0.043       0.106
# bges                                                 9.532e-06    1.6e-06      5.952      0.000    6.39e-06    1.27e-05
# ==============================================================================
# Omnibus:                      995.428   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1411.528
# Skew:                           1.031   Prob(JB):                    3.10e-307
# Kurtosis:                       2.802   Cond. No.                     1.24e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.24e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# After adding control variables to the regression model, run Variance Inflation Factor calculations for the different regression configurations to check for multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["X"] = df_merged_companies[["is_owner_change_2009_2017", "jahr_2020"]].columns
vif_data["VIF"] = [variance_inflation_factor(df_did[["is_owner_change_2009_2017", "jahr_2020"]].dropna(), i) 
                          for i in range(len(df_did[["is_owner_change_2009_2017", "jahr_2020"]].columns))]
vif_data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 3
#       1 from statsmodels.stats.outliers_influence import variance_inflation_factor
#       2 vif_data = pd.DataFrame()
# ----> 3 vif_data["X"] = df_merged_companies[["is_owner_change_2009_2017", "jahr_2020"]].columns
#       4 vif_data["VIF"] = [variance_inflation_factor(df_did[["is_owner_change_2009_2017", "jahr_2020"]].dropna(), i)
#       5                           for i in range(len(df_did[["is_owner_change_2009_2017", "jahr_2020"]].columns))]
#       6 vif_data
#
# File c:\Users\lucas\anaconda3\Lib\site-packages\pandas\core\frame.py:3902, in DataFrame.__getitem__(self, key)
#    3900     if is_iterator(key):
#    3901         key = list(key)
# -> 3902     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3904 # take() does not accept boolean indexers
#    3905 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\lucas\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File c:\Users\lucas\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6178, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['jahr_2020'] not in index"

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["X"] = df_did[["is_owner_change_2009_2017","jahr_2020", "bges"]].columns
vif_data["VIF"] = [variance_inflation_factor(df_did[["is_owner_change_2009_2017","jahr_2020", "bges"]].dropna(), i) 
                          for i in range(len(df_did[["is_owner_change_2009_2017","jahr_2020", "bges"]].columns))]
vif_data
# Out:
#                            X       VIF
# 0  is_owner_change_2009_2017  1.118296
# 1                  jahr_2020  1.119280
# 2                       bges  1.002389

# %% [markdown]
# I was not able to run the VIF with branche since it is not numerical

# %% [markdown]
# #Regression with `df_merged_owners`

# %% [markdown]
# Keeping the data together like this doesn't result in anything significant, too few entries

# %%
#Loop over all possible dependent variables
for y in dependent_variables:
    df_did = df_merged_companies[(df_merged_companies["jahr"] == 2008) | (df_merged_companies["jahr"] == 2020)]
    df_did = df_did[["companyid", "jahr", y, "is_ownerid_change_2009_2017", "bges", "branche"]]
    df_did = pd.merge(df_did, df_merged_owners[['companyid', 'ownerid', 'jahr', y, 'bges', 'branche']], on=['companyid', 'jahr'], how='left')
    df_did["jahr_2020"] = np.where(df_did["jahr"] == 2020, 1, 0)
    df_did["is_ownerid_change_2009_2017"] = np.where(df_did["is_ownerid_change_2009_2017"] == True, 1, 0)
    # Set up the difference-in-differences model
    model_did = smf.ols(formula=y + "_y" + ' ~ is_ownerid_change_2009_2017 + jahr_2020 + is_ownerid_change_2009_2017:jahr_2020', data=df_did)

    # Fit the model
    results_did = model_did.fit()

    # Print the model summary
    print("Regression results for " + y + " in the period 2009-2017 for owners:\n")
    print(results_did.summary())
    print("\n\n")
# Out:
# Regression results for oekpz_avg in the period 2009-2017 for owners:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            oekpz_avg_y   R-squared:                       0.077
# Model:                            OLS   Adj. R-squared:                  0.068
# Method:                 Least Squares   F-statistic:                     8.389
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           2.26e-05
# Time:                        18:15:35   Log-Likelihood:                -273.47
# No. Observations:                 304   AIC:                             554.9
# Df Residuals:                     300   BIC:                             569.8
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                 0.6509      0.050     13.088      0.000       0.553       0.749
# is_ownerid_change_2009_2017               0.1854      0.146      1.269      0.206      -0.102       0.473
# jahr_2020                                -0.3260      0.078     -4.188      0.000      -0.479      -0.173
# is_ownerid_change_2009_2017:jahr_2020    -0.1345      0.184     -0.731      0.466      -0.497       0.228
# ==============================================================================
# Omnibus:                       33.287   Durbin-Watson:                   2.066
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.162
# Skew:                           0.912   Prob(JB):                     6.99e-10
# Kurtosis:                       2.996   Cond. No.                         7.64
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for oekpd_avg in the period 2009-2017 for owners:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            oekpd_avg_y   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     8.708
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           1.50e-05
# Time:                        18:15:35   Log-Likelihood:                -302.37
# No. Observations:                 297   AIC:                             612.7
# Df Residuals:                     293   BIC:                             627.5
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                 0.7536      0.057     13.223      0.000       0.641       0.866
# is_ownerid_change_2009_2017               0.1938      0.165      1.176      0.241      -0.131       0.518
# jahr_2020                                -0.3939      0.089     -4.435      0.000      -0.569      -0.219
# is_ownerid_change_2009_2017:jahr_2020    -0.0785      0.208     -0.378      0.706      -0.487       0.330
# ==============================================================================
# Omnibus:                       41.305   Durbin-Watson:                   2.011
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.746
# Skew:                           0.546   Prob(JB):                     6.98e-06
# Kurtosis:                       2.148   Cond. No.                         7.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for energy_consumption in the period 2009-2017 for owners:
#
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     energy_consumption_y   R-squared:                       0.023
# Model:                              OLS   Adj. R-squared:                  0.013
# Method:                   Least Squares   F-statistic:                     2.308
# Date:                  Sat, 06 Jan 2024   Prob (F-statistic):             0.0767
# Time:                          18:15:36   Log-Likelihood:                -363.78
# No. Observations:                   302   AIC:                             735.6
# Df Residuals:                       298   BIC:                             750.4
# Df Model:                             3
# Covariance Type:              nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                 0.8182      0.068     12.043      0.000       0.684       0.952
# is_ownerid_change_2009_2017               0.1292      0.198      0.651      0.515      -0.261       0.520
# jahr_2020                                -0.2482      0.106     -2.343      0.020      -0.457      -0.040
# is_ownerid_change_2009_2017:jahr_2020     0.0258      0.250      0.103      0.918      -0.466       0.518
# ==============================================================================
# Omnibus:                      657.964   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.575
# Skew:                           0.431   Prob(JB):                     8.44e-08
# Kurtosis:                       1.642   Cond. No.                         7.63
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for material_use in the period 2009-2017 for owners:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         material_use_y   R-squared:                       0.061
# Model:                            OLS   Adj. R-squared:                  0.051
# Method:                 Least Squares   F-statistic:                     6.390
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           0.000330
# Time:                        18:15:36   Log-Likelihood:                -340.89
# No. Observations:                 299   AIC:                             689.8
# Df Residuals:                     295   BIC:                             704.6
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                 0.6667      0.064     10.392      0.000       0.540       0.793
# is_ownerid_change_2009_2017               0.3333      0.191      1.748      0.081      -0.042       0.709
# jahr_2020                                -0.3167      0.100     -3.180      0.002      -0.513      -0.121
# is_ownerid_change_2009_2017:jahr_2020    -0.3333      0.238     -1.400      0.162      -0.802       0.135
# ==============================================================================
# Omnibus:                       41.900   Durbin-Watson:                   1.884
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               42.886
# Skew:                           0.866   Prob(JB):                     4.87e-10
# Kurtosis:                       2.332   Cond. No.                         7.76
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for emissions_CO2 in the period 2009-2017 for owners:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        emissions_CO2_y   R-squared:                       0.058
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     6.097
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           0.000489
# Time:                        18:15:37   Log-Likelihood:                -355.68
# No. Observations:                 299   AIC:                             719.4
# Df Residuals:                     295   BIC:                             734.2
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                 0.8156      0.067     12.100      0.000       0.683       0.948
# is_ownerid_change_2009_2017               0.0791      0.196      0.405      0.686      -0.306       0.464
# jahr_2020                                -0.4015      0.105     -3.825      0.000      -0.608      -0.195
# is_ownerid_change_2009_2017:jahr_2020    -0.0183      0.246     -0.074      0.941      -0.503       0.467
# ==============================================================================
# Omnibus:                      165.417   Durbin-Watson:                   1.909
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               33.234
# Skew:                           0.560   Prob(JB):                     6.07e-08
# Kurtosis:                       1.810   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for emissions_other in the period 2009-2017 for owners:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      emissions_other_y   R-squared:                       0.074
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     7.913
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           4.30e-05
# Time:                        18:15:37   Log-Likelihood:                -328.77
# No. Observations:                 299   AIC:                             665.5
# Df Residuals:                     295   BIC:                             680.3
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                 0.6454      0.062     10.476      0.000       0.524       0.767
# is_ownerid_change_2009_2017               0.1441      0.179      0.806      0.421      -0.208       0.496
# jahr_2020                                -0.4131      0.096     -4.306      0.000      -0.602      -0.224
# is_ownerid_change_2009_2017:jahr_2020    -0.0514      0.225     -0.228      0.820      -0.495       0.392
# ==============================================================================
# Omnibus:                       39.549   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.526
# Skew:                           0.943   Prob(JB):                     4.78e-11
# Kurtosis:                       2.492   Cond. No.                         7.61
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for hazardous_material in the period 2009-2017 for owners:
#
#                              OLS Regression Results
# ================================================================================
# Dep. Variable:     hazardous_material_y   R-squared:                       0.067
# Model:                              OLS   Adj. R-squared:                  0.058
# Method:                   Least Squares   F-statistic:                     6.970
# Date:                  Sat, 06 Jan 2024   Prob (F-statistic):           0.000152
# Time:                          18:15:38   Log-Likelihood:                -309.97
# No. Observations:                   294   AIC:                             627.9
# Df Residuals:                       290   BIC:                             642.7
# Df Model:                             3
# Covariance Type:              nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                 0.5000      0.060      8.339      0.000       0.382       0.618
# is_ownerid_change_2009_2017               0.3889      0.175      2.217      0.027       0.044       0.734
# jahr_2020                                -0.2600      0.092     -2.823      0.005      -0.441      -0.079
# is_ownerid_change_2009_2017:jahr_2020    -0.4539      0.219     -2.074      0.039      -0.885      -0.023
# ==============================================================================
# Omnibus:                       59.429   Durbin-Watson:                   1.954
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               91.085
# Skew:                           1.342   Prob(JB):                     1.66e-20
# Kurtosis:                       3.479   Cond. No.                         7.75
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for recycling in the period 2009-2017 for owners:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            recycling_y   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.027
# Method:                 Least Squares   F-statistic:                     3.707
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):             0.0121
# Time:                        18:15:38   Log-Likelihood:                -329.73
# No. Observations:                 289   AIC:                             667.5
# Df Residuals:                     285   BIC:                             682.1
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# Intercept                                 0.6176      0.065      9.445      0.000       0.489       0.746
# is_ownerid_change_2009_2017               0.2157      0.191      1.128      0.260      -0.161       0.592
# jahr_2020                                -0.2707      0.101     -2.679      0.008      -0.470      -0.072
# is_ownerid_change_2009_2017:jahr_2020    -0.1572      0.241     -0.651      0.515      -0.632       0.318
# ==============================================================================
# Omnibus:                       41.081   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               51.360
# Skew:                           1.003   Prob(JB):                     7.04e-12
# Kurtosis:                       2.512   Cond. No.                         7.66
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Here there is a additional dummy variable `owner` to identify if an entry is a owner (=1) or company (=0)

# %%
#Loop over all possible dependent variables
for y in dependent_variables:
    df_did = df_merged_companies[(df_merged_companies["jahr"] == 2008) | (df_merged_companies["jahr"] == 2020)]
    df_did = df_did[["companyid", "jahr", y, "is_ownerid_change_2009_2017", "bges", "branche"]]
    df_did["owner"] = 0
    df_did = pd.concat([df_did, df_merged_owners[['companyid', 'jahr', y, 'is_ownerid_change_2009_2017' ,'bges', 'branche']]], ignore_index=True)
    df_did["owner"].fillna(1, inplace=True)
    df_did["jahr_2020"] = np.where(df_did["jahr"] == 2020, 1, 0)
    df_did["is_ownerid_change_2009_2017"] = np.where(df_did["is_ownerid_change_2009_2017"] == True, 1, 0)

    # Set up the difference-in-differences model
    model_did = smf.ols(formula=y + ' ~ is_ownerid_change_2009_2017 + jahr_2020 + owner + jahr_2020:owner + is_ownerid_change_2009_2017:jahr_2020 + is_ownerid_change_2009_2017:jahr_2020:owner', data=df_did)

    # Fit the model
    results_did = model_did.fit()

    # Print the model summary
    print("Regression results for " + y + " in the period 2009-2017 for owners and companies:\n")
    print(results_did.summary())
    print("\n\n")
# Out:
# Regression results for oekpz_avg in the period 2009-2017 for owners and companies:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              oekpz_avg   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     20.71
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           2.59e-24
# Time:                        18:15:39   Log-Likelihood:                -11998.
# No. Observations:               15262   AIC:                         2.401e+04
# Df Residuals:                   15255   BIC:                         2.406e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       0.4543      0.008     58.315      0.000       0.439       0.470
# is_ownerid_change_2009_2017                     0.0751      0.038      1.992      0.046       0.001       0.149
# jahr_2020                                      -0.1086      0.012     -9.423      0.000      -0.131      -0.086
# owner                                          -0.0002      0.011     -0.016      0.987      -0.022       0.021
# jahr_2020:owner                                 0.0769      0.019      4.108      0.000       0.040       0.114
# is_ownerid_change_2009_2017:jahr_2020           0.0012      0.069      0.017      0.986      -0.135       0.137
# is_ownerid_change_2009_2017:jahr_2020:owner     0.0095      0.091      0.105      0.917      -0.169       0.188
# ==============================================================================
# Omnibus:                     2856.899   Durbin-Watson:                   1.840
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4738.992
# Skew:                           1.292   Prob(JB):                         0.00
# Kurtosis:                       3.883   Cond. No.                         28.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for oekpd_avg in the period 2009-2017 for owners and companies:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              oekpd_avg   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     6.024
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           2.63e-06
# Time:                        18:15:40   Log-Likelihood:                -13813.
# No. Observations:               15057   AIC:                         2.764e+04
# Df Residuals:                   15050   BIC:                         2.769e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       0.4519      0.009     50.633      0.000       0.434       0.469
# is_ownerid_change_2009_2017                     0.0689      0.044      1.583      0.113      -0.016       0.154
# jahr_2020                                      -0.0633      0.013     -4.789      0.000      -0.089      -0.037
# owner                                          -0.0172      0.013     -1.373      0.170      -0.042       0.007
# jahr_2020:owner                                 0.0894      0.022      4.156      0.000       0.047       0.132
# is_ownerid_change_2009_2017:jahr_2020           0.0726      0.079      0.918      0.359      -0.082       0.228
# is_ownerid_change_2009_2017:jahr_2020:owner    -0.0725      0.104     -0.698      0.485      -0.276       0.131
# ==============================================================================
# Omnibus:                     2516.258   Durbin-Watson:                   1.869
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3988.693
# Skew:                           1.246   Prob(JB):                         0.00
# Kurtosis:                       3.390   Cond. No.                         28.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for energy_consumption in the period 2009-2017 for owners and companies:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     energy_consumption   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     17.09
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           8.81e-20
# Time:                        18:15:40   Log-Likelihood:                -17492.
# No. Observations:               15073   AIC:                         3.500e+04
# Df Residuals:                   15066   BIC:                         3.505e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       0.6153      0.011     53.930      0.000       0.593       0.638
# is_ownerid_change_2009_2017                     0.0865      0.055      1.569      0.117      -0.022       0.194
# jahr_2020                                      -0.0879      0.017     -5.213      0.000      -0.121      -0.055
# owner                                           0.0724      0.016      4.515      0.000       0.041       0.104
# jahr_2020:owner                                 0.0515      0.027      1.882      0.060      -0.002       0.105
# is_ownerid_change_2009_2017:jahr_2020           0.0684      0.101      0.677      0.498      -0.130       0.266
# is_ownerid_change_2009_2017:jahr_2020:owner     0.0073      0.133      0.055      0.956      -0.253       0.267
# ==============================================================================
# Omnibus:                     3573.002   Durbin-Watson:                   1.856
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1963.271
# Skew:                           0.751   Prob(JB):                         0.00
# Kurtosis:                       2.067   Cond. No.                         28.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for material_use in the period 2009-2017 for owners and companies:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           material_use   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     28.09
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           1.43e-33
# Time:                        18:15:41   Log-Likelihood:                -16277.
# No. Observations:               14981   AIC:                         3.257e+04
# Df Residuals:                   14974   BIC:                         3.262e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       0.5454      0.011     51.410      0.000       0.525       0.566
# is_ownerid_change_2009_2017                     0.0887      0.051      1.730      0.084      -0.012       0.189
# jahr_2020                                      -0.1842      0.016    -11.734      0.000      -0.215      -0.153
# owner                                          -0.0226      0.015     -1.516      0.130      -0.052       0.007
# jahr_2020:owner                                 0.1226      0.026      4.806      0.000       0.073       0.173
# is_ownerid_change_2009_2017:jahr_2020           0.0024      0.094      0.025      0.980      -0.182       0.187
# is_ownerid_change_2009_2017:jahr_2020:owner    -0.0608      0.124     -0.492      0.623      -0.303       0.181
# ==============================================================================
# Omnibus:                     2079.345   Durbin-Watson:                   1.895
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3034.726
# Skew:                           1.096   Prob(JB):                         0.00
# Kurtosis:                       2.755   Cond. No.                         28.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for emissions_CO2 in the period 2009-2017 for owners and companies:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          emissions_CO2   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     10.74
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           5.98e-12
# Time:                        18:15:41   Log-Likelihood:                -16620.
# No. Observations:               14939   AIC:                         3.325e+04
# Df Residuals:                   14932   BIC:                         3.331e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       0.5032      0.011     46.133      0.000       0.482       0.525
# is_ownerid_change_2009_2017                     0.1006      0.053      1.905      0.057      -0.003       0.204
# jahr_2020                                      -0.0786      0.016     -4.873      0.000      -0.110      -0.047
# owner                                           0.0230      0.015      1.495      0.135      -0.007       0.053
# jahr_2020:owner                                 0.1006      0.026      3.842      0.000       0.049       0.152
# is_ownerid_change_2009_2017:jahr_2020           0.1219      0.096      1.264      0.206      -0.067       0.311
# is_ownerid_change_2009_2017:jahr_2020:owner    -0.1096      0.127     -0.866      0.386      -0.358       0.138
# ==============================================================================
# Omnibus:                     2101.453   Durbin-Watson:                   1.865
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3032.364
# Skew:                           1.093   Prob(JB):                         0.00
# Kurtosis:                       2.689   Cond. No.                         28.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for emissions_other in the period 2009-2017 for owners and companies:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        emissions_other   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     13.22
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           5.48e-15
# Time:                        18:15:41   Log-Likelihood:                -14506.
# No. Observations:               14843   AIC:                         2.903e+04
# Df Residuals:                   14836   BIC:                         2.908e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       0.3630      0.010     37.985      0.000       0.344       0.382
# is_ownerid_change_2009_2017                     0.1130      0.046      2.432      0.015       0.022       0.204
# jahr_2020                                      -0.1024      0.014     -7.252      0.000      -0.130      -0.075
# owner                                          -0.0037      0.013     -0.274      0.784      -0.030       0.023
# jahr_2020:owner                                 0.0874      0.023      3.804      0.000       0.042       0.132
# is_ownerid_change_2009_2017:jahr_2020           0.0147      0.084      0.174      0.862      -0.151       0.180
# is_ownerid_change_2009_2017:jahr_2020:owner     0.0108      0.111      0.097      0.922      -0.207       0.229
# ==============================================================================
# Omnibus:                     4032.211   Durbin-Watson:                   1.851
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8260.878
# Skew:                           1.682   Prob(JB):                         0.00
# Kurtosis:                       4.430   Cond. No.                         28.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for hazardous_material in the period 2009-2017 for owners and companies:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     hazardous_material   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     17.53
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           2.50e-20
# Time:                        18:15:42   Log-Likelihood:                -13837.
# No. Observations:               14759   AIC:                         2.769e+04
# Df Residuals:                   14752   BIC:                         2.774e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       0.3599      0.009     39.114      0.000       0.342       0.378
# is_ownerid_change_2009_2017                    -0.0002      0.045     -0.005      0.996      -0.088       0.088
# jahr_2020                                      -0.1281      0.014     -9.412      0.000      -0.155      -0.101
# owner                                          -0.0314      0.013     -2.424      0.015      -0.057      -0.006
# jahr_2020:owner                                 0.0607      0.022      2.741      0.006       0.017       0.104
# is_ownerid_change_2009_2017:jahr_2020           0.0304      0.082      0.372      0.710      -0.130       0.190
# is_ownerid_change_2009_2017:jahr_2020:owner     0.0364      0.107      0.340      0.734      -0.173       0.246
# ==============================================================================
# Omnibus:                     4559.385   Durbin-Watson:                   1.823
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10451.829
# Skew:                           1.816   Prob(JB):                         0.00
# Kurtosis:                       4.951   Cond. No.                         28.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
#
# Regression results for recycling in the period 2009-2017 for owners and companies:
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              recycling   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.007
# Method:                 Least Squares   F-statistic:                     19.33
# Date:                Sat, 06 Jan 2024   Prob (F-statistic):           1.39e-22
# Time:                        18:15:42   Log-Likelihood:                -16393.
# No. Observations:               14833   AIC:                         3.280e+04
# Df Residuals:                   14826   BIC:                         3.285e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ===============================================================================================================
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# Intercept                                       0.5548      0.011     51.228      0.000       0.534       0.576
# is_ownerid_change_2009_2017                     0.0562      0.053      1.068      0.286      -0.047       0.159
# jahr_2020                                      -0.1628      0.016    -10.128      0.000      -0.194      -0.131
# owner                                          -0.0553      0.015     -3.625      0.000      -0.085      -0.025
# jahr_2020:owner                                 0.1000      0.026      3.825      0.000       0.049       0.151
# is_ownerid_change_2009_2017:jahr_2020          -0.0038      0.098     -0.039      0.969      -0.195       0.187
# is_ownerid_change_2009_2017:jahr_2020:owner    -0.0070      0.129     -0.055      0.956      -0.259       0.245
# ==============================================================================
# Omnibus:                     2135.276   Durbin-Watson:                   1.854
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3169.610
# Skew:                           1.126   Prob(JB):                         0.00
# Kurtosis:                       2.767   Cond. No.                         28.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Save the data

# %%
df_merged_companies.to_csv(r"C:\Users\lucas\OneDrive\BA\Data\outputs\merged_companies_reganalysis.csv")
df_merged_owners.to_csv(r"C:\Users\lucas\OneDrive\BA\Data\outputs\merged_owners_reganalysis.csv")
